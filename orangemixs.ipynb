# %%
# !git clone https://gitgud.io/AUTOMATIC1111/stable-diffusion-webui.git
# %pip install -q https://github.com/nolanaatama/xformers-wheels/releases/download/xformers/xformers-0.0.15.dev0+4c06c79.d20221205-cp38-cp38-linux_x86_64.whl

###########################################################################################################################################################

# Remove '#' from the beginning of '!curl' and '!mv' line of your choosen models.

###########################################################################################################################################################

#Eerie
#base 1
#!curl -Lo EerieOrangeMix_base.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/EerieOrangeMix/EerieOrangeMix_base.ckpt'
#!mv "/content/EerieOrangeMix_base.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

#night 1
#!curl -Lo EerieOrangeMix_night.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/EerieOrangeMix/EerieOrangeMix_night.safetensors'
#!mv "/content/EerieOrangeMix_night.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

#half 1
#!curl -Lo EerieOrangeMix_half.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/EerieOrangeMix/EerieOrangeMix_half.safetensors'
#!mv "/content/EerieOrangeMix_half.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

#unlabeled 1
#!curl -Lo EerieOrangeMix.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/EerieOrangeMix/EerieOrangeMix.safetensors'
#!mv "/content/EerieOrangeMix.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

#################

#EerieOrangeMix2
#base 2
#!curl -Lo EerieOrangeMix2_base.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/EerieOrangeMix/EerieOrangeMix2_base.ckpt'
#!mv "/content/EerieOrangeMix2_base.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

#night 2
#!curl -Lo EerieOrangeMix2_night.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/EerieOrangeMix/EerieOrangeMix2_night.safetensors'
#!mv "/content/EerieOrangeMix2_night.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

#half 2
#!curl -Lo EerieOrangeMix2_half.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/EerieOrangeMix/EerieOrangeMix2_half.safetensors'
#!mv "/content/EerieOrangeMix2_half.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

#unlabeled 2
#!curl -Lo EerieOrangeMix2.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/EerieOrangeMix/EerieOrangeMix2.safetensors'
#!mv "/content/EerieOrangeMix2.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

###########################################################################################################################################################

#Abyss
#base
#!curl -Lo AbyssOrangeMix_base.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/AbyssOrangeMix_base.ckpt'
#!mv "/content/AbyssOrangeMix_base.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

#night
#!curl -Lo AbyssOrangeMix_Night.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/AbyssOrangeMix_Night.safetensors'
#!mv "/content/AbyssOrangeMix_Night.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

#half
#!curl -Lo AbyssOrangeMix_half.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/AbyssOrangeMix_half.safetensors'
#!mv "/content/AbyssOrangeMix_half.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

#unlabeled
#!curl -Lo AbyssOrangeMix.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/AbyssOrangeMix.safetensors'
#!mv "/content/AbyssOrangeMix.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

###########################################################################################################################################################

#Ely
#night
#!curl -Lo ElyNightOrangeMix.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/ElyNightOrangeMix.ckpt'
#!mv "/content/ElyNightOrangeMix.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

#half
#!curl -Lo ElyOrangeMix_half.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/ElyOrangeMix_half.ckpt'
#!mv "/content/ElyOrangeMix_half.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

#unlabeled
#!curl -Lo ElyOrangeMix.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/ElyOrangeMix.ckpt'
#!mv "/content/ElyOrangeMix.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

###########################################################################################################################################################

#Blood
#night
#!curl -Lo BloodNightOrangeMix.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/BloodNightOrangeMix.ckpt'
#!mv "/content/BloodNightOrangeMix.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

#half
#!curl -Lo BloodOrangeMix_half.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/BloodOrangeMix_half.ckpt'
#!mv "/content/BloodOrangeMix_half.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

#unlabeled
#!curl -Lo BloodOrangeMix.safetensors 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/BloodOrangeMix.safetensors'
#!mv "/content/BloodOrangeMix.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"

###########################################################################################################################################################

#Elder
#unlabeled
#!curl -Lo ElderOrangeMix.ckpt 'https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/ElderOrangeMix.ckpt'
#!mv "/content/ElderOrangeMix.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"

###########################################################################################################################################################

# %cd /content/stable-diffusion-webui
# !git checkout 11d432d # temporary fix
# !COMMANDLINE_ARGS="--share --gradio-debug --medvram --disable-safe-unpickle --xformers" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# # 📚 GitHub for more: [_@nolanaatama_](https://github.com/nolanaatama)
# # 📦 Repo: [Github](https://github.com/nolanaatama/sd-colab)
